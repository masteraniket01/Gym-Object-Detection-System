# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Clone GitHub repository, install all dependencies/required library and check PyTorch and GPU

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-278-g050c72c Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %% [markdown]
# ##To unzip the Train data and val data

# %%
# !unzip -q /content/data.zip -d /content

# %% [markdown]
# ## Train on Custom Data medium model and i also tried with small model

# %%
# !python train.py --img 640 --batch 8 --epochs 100 --data coco128.yaml --weights yolov5m.pt --nosave --cache
# Out:
# 2024-01-24 08:25:00.889514: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-24 08:25:00.889571: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-24 08:25:00.891536: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Visualize the result

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# ## To get the object detection output

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/last.pt --img 640 --conf 0.3 --source /content/gym.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (570/5567) /content/gym.mp4: 384x640 3 Plates, 9.2ms
# video 1/1 (571/5567) /content/gym.mp4: 384x640 3 Plates, 9.2ms
# video 1/1 (572/5567) /content/gym.mp4: 384x640 3 Plates, 11.0ms
# video 1/1 (573/5567) /content/gym.mp4: 384x640 3 Plates, 9.0ms
# video 1/1 (574/5567) /content/gym.mp4: 384x640 4 Plates, 8.9ms
# video 1/1 (575/5567) /content/gym.mp4: 384x640 3 Plates, 8.9ms
# video 1/1 (576/5567) /content/gym.mp4: 384x640 3 Plates, 8.9ms
# video 1/1 (577/5567) /content/gym.mp4: 384x640 3 Plates, 8.9ms
# video 1/1 (578/5567) /content/gym.mp4: 384x640 3 Plates, 9.1ms
# video 1/1 (579/5567) /content/gym.mp4: 384x640 3 Plates, 9.2ms
# video 1/1 (580/5567) /content/gym.mp4: 384x640 3 Plates, 9.0ms
# video 1/1 (581/5567) /content/gym.mp4: 384x640 4 Plates, 9.4ms
# video 1/1 (582/5567) /content/gym.mp4: 384x640 4 Plates, 8.9ms
# video 1/1 (583/5567) /content/gym.mp4: 384x640 1 Dumbbell, 3 Plates, 8.9ms
# ...
